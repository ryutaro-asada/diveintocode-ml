# %% [markdown]
# # 準備

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import sklearn 
import pandas as pd

# %%
import pandas as pd
df=pd.read_csv('/Users/user/Downloads/house-prices-advanced-regression-techniques/train.csv')

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# ## 【問題1】練習のために特徴量の選択
# データセットを読み込んだ後、GrLivAreaとYearBuiltを抜き出してください。

# %%
X = df[['GrLivArea', 'YearBuilt']]
y  = df.SalePrice

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# ## 【問題2】線形回帰による推定と評価
# データを簡単に分析、前処理し、 線形回帰 による学習、推定、評価、可視化までの一連の流れを作成・実行してください
# sklearn.linear_model.LinearRegression — scikit-learn 0.21.3 documentation
# 評価のための指標値は回帰問題では 平均二乗誤差（Mean Squared Error, MSE）を使うことが一般的です。
# sklearn.metrics.mean_squared_error — scikit-learn 0.21.3 documentation
# 可視化は横軸にある特徴量、縦軸に推測した住宅価格といった方法で行えます。

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
lir = LinearRegression()
lir.fit(X_train, y_train)
predict_lir = lir.predict(X_test)
print(' LinearRegression')
print('X_trainは{}'.format(X_train.shape))
print('X_testは{}'.format(X_test.shape))
print('y_trainは{}'.format(y_train.shape))
print('y_testは{}'.format(y_test.shape))
print('mean_squared_error = {}'.format(mean_squared_error(y_test, predict_lir)))

print('coefficient = ', lir.coef_) # 説明変数の係数を出力
print('intercept = ', lir.intercept_) # 切片を出力
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dd270f54b52d> in <module>
#       2 from sklearn.metrics import mean_squared_error
#       3 lir = LinearRegression()
# ----> 4 lir.fit(X_train, y_train)
#       5 predict_lir = lir.predict(X_test)
#       6 print(' LinearRegression')
#
# NameError: name 'X_train' is not defined

# %%
from mpl_toolkits.mplot3d import Axes3D  #3Dplot
import matplotlib.pyplot as plt
import seaborn as sns

fig=plt.figure()
ax=Axes3D(fig)

X1 = np.linspace(470, 4316, 10)                             # x軸を作成
X2 = np.linspace(1870, 2009, 10)                             # y軸を作成
X, Y = np.meshgrid(X1, X2)                             # x軸とy軸からグリッドデータを作成
reg_wn = lir.coef_                       # 偏回帰係数
reg_w0 = lir.intercept_                  # 切片
Z = reg_w0 + (reg_wn[0] * X) + (reg_wn[1] * Y)   # 回帰平面のz値を作成
ax.plot_wireframe(X, Y, Z, label='Regression plane', alpha = 0.5, color = 'y')

ax.scatter3D(X_test.GrLivArea, X_test.YearBuilt, predict_lir, color = 'r')
ax.set_xlabel("GrLivArea")
ax.set_ylabel("YearBuilt")
ax.set_zlabel("SalePrice")

# h_angle = 30
# v_angle = 30
# ax.view_init(v_angle, h_angle)

# rotate the axes and update
# for angle in range(0, 360,60):
# #     ax.view_init(30, angle)
# #     plt.draw()
# #     plt.pause(5)
# Out:
# Text(0.5, 0, 'SalePrice')

# %% [markdown]
# ## 【問題3】手法の比較
# 以下の全ての手法について学習・推定・評価・可視化を行ってください。そして、指標値を１つの表にまとめてください。その表と可視化した図を利用して結果を簡単に考察してください。どの手法がどの指標値が良かったかや、どういった図になっていたかを述べてください。
#
#
# 線形回帰
# SVM
# 決定木
# ランダムフォレスト
#
#   公式ドキュメントへのリンクは以下です。本来はパラメータチューニングを行いますが、まずはデフォルトの値で実行しましょう
#    sklearn.linear_model.LinearRegression — scikit-learn 0.21.3 documentation
# sklearn.svm.SVR — scikit-learn 0.21.3 documentation
# sklearn.tree.DecisionTreeRegressor — scikit-learn 0.21.3 documentation
# sklearn.ensemble.RandomForestRegressor — scikit-learn 0.21.3 documentation
# SVM、決定木、ランダムフォレストは分類問題でも使用した手法ですが、回帰問題用のライブラリはそれぞれ専用のものに分かれています。

# %% [markdown]
# ##  各手法による学習・推定・評価
# ### 線形回帰
# ### SVM
# ### 決定木
# ### ランダムフォレスト

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor


# 線形回帰
lir = LinearRegression()
lir.fit(X_train, y_train)
predict_lir = lir.predict(X_test)
MSE_LR = mean_squared_error(y_test, predict_lir)
print('LinearRegression')
print('mean_squared_error = {}'.format(mean_squared_error(y_test, predict_lir)))
print('')
# SVM
svr = SVR(kernel="linear")
svr.fit(X_train, y_train)
predict_svr = svr.predict(X_test)
MSE_SVR = mean_squared_error(y_test, predict_svr)
print('SVR')
print('mean_squared_error = {}'.format(mean_squared_error(y_test, predict_svr)))
print('')
# 決定木
dtr = DecisionTreeRegressor()
dtr.fit(X_train, y_train)
predict_dtr = dtr.predict(X_test)
MSE_DTR = mean_squared_error(y_test, predict_dtr)
print('DecisionTreeRegressor')
print('mean_squared_error = {}'.format(mean_squared_error(y_test, predict_dtr)))
print('')
# ランダムフォレスト¶
rfr = RandomForestRegressor()
rfr.fit(X_train, y_train)
predict_rfr = rfr.predict(X_test)
MSE_RFR = mean_squared_error(y_test, predict_rfr)
print('RandomForestRegressor')
print('mean_squared_error = {}'.format(mean_squared_error(y_test, predict_rfr)))
# Out:
# LinearRegression
# mean_squared_error = 2314465092.732014
#
# SVR
# mean_squared_error = 2457801943.654603
#
# DecisionTreeRegressor
# mean_squared_error = 2369116259.085921
#
# RandomForestRegressor
# mean_squared_error = 1686212235.8646176
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
plt.title('SalePrice and GrLivArea with LR', size = 10)
plt.scatter(X_test.GrLivArea, predict_lir , c='c',label = 'predicted')
plt.scatter(X_test.GrLivArea, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')
plt.show()

plt.title('SalePrice and YearBuilt with LR', size = 10)
plt.scatter(X_test.YearBuilt, predict_lir , c='c',label = 'predicted')
plt.scatter(X_test.YearBuilt, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('YearBuilt')
plt.ylabel('SalePrice')
plt.show()

# %%
plt.title('SalePrice and GrLivArea with SVM', size = 10)
plt.scatter(X_test.GrLivArea, predict_svr , c='c',label = 'predicted')
plt.scatter(X_test.GrLivArea, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')
plt.show()

plt.title('SalePrice and YearBuilt with SVM', size = 10)
plt.scatter(X_test.YearBuilt, predict_svr , c='c',label = 'predicted')
plt.scatter(X_test.YearBuilt, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('YearBuilt')
plt.ylabel('SalePrice')
plt.show()

# %%
plt.title('SalePrice and GrLivArea with DTR' )
plt.scatter(X_test.GrLivArea, predict_dtr , c='c',label = 'predicted')
plt.scatter(X_test.GrLivArea, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')
plt.show()

plt.title('SalePrice and YearBuilt with DTR')
plt.scatter(X_test.YearBuilt, predict_dtr , c='c',label = 'predicted')
plt.scatter(X_test.YearBuilt, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('YearBuilt')
plt.ylabel('SalePrice')
plt.show()

# %%
plt.title('SalePrice and GrLivArea with RFR')
plt.scatter(X_test.GrLivArea, predict_rfr , c='c',label = 'predicted')
plt.scatter(X_test.GrLivArea, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')
plt.show()

plt.title('SalePrice and YearBuilt with RFR')
plt.scatter(X_test.YearBuilt, predict_rfr , c='c',label = 'predicted')
plt.scatter(X_test.YearBuilt, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('YearBuilt')
plt.ylabel('SalePrice')
plt.show()

# %% [markdown]
# ## 対数変換、標準化

# %%
from sklearn.preprocessing import StandardScaler

X_train_log = np.log(X_train)
y_train_log = np.log(y_train)
X_test_log = np.log(X_test)
y_test_log = np.log(y_test)

scaler_x_train = StandardScaler()
scaler_x_test = StandardScaler()

scaler_x_train.fit(X_train_log)
scaler_x_test.fit(X_test_log)

X_train_scaled = scaler_x_train.transform(X_train_log)
X_test_scaled = scaler_x_test.transform(X_test_log)

# %%
# 線形回帰
lir = LinearRegression()
lir.fit(X_train_scaled, y_train_log)
predict_lir_log_st = lir.predict(X_test_scaled)
print('LinearRegression')
print('mean_squared_error = {}'.format(mean_squared_error(y_test_log, predict_lir_log_st)))
print('')
# SVM
svr = SVR(kernel="linear")
svr.fit(X_train_scaled, y_train_log)
predict_svr_log_st = svr.predict(X_test_scaled)
print('SVR')
print('mean_squared_error = {}'.format(mean_squared_error(y_test_log, predict_svr_log_st)))
print('')
# 決定木
dtr = DecisionTreeRegressor()
dtr.fit(X_train_scaled, y_train_log)
predict_dtr_log_st = dtr.predict(X_test_scaled)
print('DecisionTreeRegressor')
print('mean_squared_error = {}'.format(mean_squared_error(y_test_log, predict_dtr_log_st)))
print('')
# ランダムフォレスト¶
rfr = RandomForestRegressor()
rfr.fit(X_train_scaled, y_train_log)
predict_rfr_log_st = rfr.predict(X_test_scaled)
print('RandomForestRegressor')
print('mean_squared_error = {}'.format(mean_squared_error(y_test_log, predict_rfr_log_st)))

MSE_LR_loged = mean_squared_error(y_test_log, predict_lir_log_st)
MSE_SVR_loged = mean_squared_error(y_test_log, predict_svr_log_st)
MSE_DTR_loged = mean_squared_error(y_test_log, predict_dtr_log_st)
MSE_RFR_loged = mean_squared_error(y_test_log, predict_rfr_log_st)
# Out:
# LinearRegression
# mean_squared_error = 0.04949382712129632
#
# SVR
# mean_squared_error = 0.04969160007871367
#
# DecisionTreeRegressor
# mean_squared_error = 0.09070209400325195
#
# RandomForestRegressor
# mean_squared_error = 0.05834842978643794
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
predicted_lir_reversed = np.exp(predict_lir_log_st)
predicted_svr_reversed = np.exp(predict_svr_log_st)
predicted_dtr_reversed = np.exp(predict_dtr_log_st)
predicted_rfr_reversed = np.exp(predict_rfr_log_st)

# %%
plt.figure(figsize=(15, 10))
plt.subplot(221)
plt.title('NO_log with LR', size = 10)
plt.scatter(X_test.GrLivArea, predict_lir , c='c',label = 'predicted')
plt.scatter(X_test.GrLivArea, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')

plt.subplot(222)
plt.title('loged with LR', size = 10)
plt.scatter(X_test.GrLivArea, predicted_lir_reversed , c='c',label = 'predicted')
plt.scatter(X_test.GrLivArea, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')

plt.subplot(223)
plt.title('No_log with LR', size = 10)
plt.scatter(X_test.YearBuilt, predict_lir , c='c',label = 'predicted')
plt.scatter(X_test.YearBuilt, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('YearBuilt')
plt.ylabel('SalePrice')

plt.subplot(224)
plt.title('loged with LR', size = 10)
plt.scatter(X_test.YearBuilt, predicted_lir_reversed , c='c',label = 'predicted')
plt.scatter(X_test.YearBuilt, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('YearBuilt')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
plt.figure(figsize=(15, 10))
plt.subplot(221)
plt.title('NO_log with SVM', size = 10)
plt.scatter(X_test.GrLivArea, predict_svr , c='c',label = 'predicted')
plt.scatter(X_test.GrLivArea, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')

plt.subplot(222)
plt.title('loged with SVM', size = 10)
plt.scatter(X_test.GrLivArea, predicted_svr_reversed , c='c',label = 'predicted')
plt.scatter(X_test.GrLivArea, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')

plt.subplot(223)
plt.title('No_log with SVM', size = 10)
plt.scatter(X_test.YearBuilt, predict_svr , c='c',label = 'predicted')
plt.scatter(X_test.YearBuilt, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('YearBuilt')
plt.ylabel('SalePrice')

plt.subplot(224)
plt.title('loged with SVM', size = 10)
plt.scatter(X_test.YearBuilt, predicted_svr_reversed , c='c',label = 'predicted')
plt.scatter(X_test.YearBuilt, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('YearBuilt')
plt.ylabel('SalePrice')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.subplot(221)
plt.title('NO_log with DTR', size = 10)
plt.scatter(X_test.GrLivArea,predict_dtr , c='c',label = 'predicted')
plt.scatter(X_test.GrLivArea, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')

plt.subplot(222)
plt.title('loged with DTR', size = 10)
plt.scatter(X_test.GrLivArea, predicted_dtr_reversed , c='c',label = 'predicted')
plt.scatter(X_test.GrLivArea, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')

plt.subplot(223)
plt.title('No_log with DTR', size = 10)
plt.scatter(X_test.YearBuilt, predict_dtr , c='c',label = 'predicted')
plt.scatter(X_test.YearBuilt, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('YearBuilt')
plt.ylabel('SalePrice')

plt.subplot(224)
plt.title('loged with DTR', size = 10)
plt.scatter(X_test.YearBuilt, predicted_dtr_reversed , c='c',label = 'predicted')
plt.scatter(X_test.YearBuilt, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('YearBuilt')
plt.ylabel('SalePrice')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.subplot(221)
plt.title('NO_log with RFR', size = 10)
plt.scatter(X_test.GrLivArea,predict_rfr  , c='c',label = 'predicted')
plt.scatter(X_test.GrLivArea, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')

plt.subplot(222)
plt.title('loged with RFR', size = 10)
plt.scatter(X_test.GrLivArea, predicted_rfr_reversed , c='c',label = 'predicted')
plt.scatter(X_test.GrLivArea, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')

plt.subplot(223)
plt.title('No_log with RFR', size = 10)
plt.scatter(X_test.YearBuilt, predict_rfr  , c='c',label = 'predicted')
plt.scatter(X_test.YearBuilt, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('YearBuilt')
plt.ylabel('SalePrice')

plt.subplot(224)
plt.title('loged with RFR', size = 10)
plt.scatter(X_test.YearBuilt, predicted_rfr_reversed , c='c',label = 'predicted')
plt.scatter(X_test.YearBuilt, y_test , c='r',label = 'real')
plt.legend()
plt.xlabel('YearBuilt')
plt.ylabel('SalePrice')
plt.show()

# %%
MSE_list_loged = [MSE_LR_loged,
                    MSE_SVR_loged,
                    MSE_DTR_loged,
                    MSE_RFR_loged]

MSE_list = [MSE_LR,
            MSE_SVR,
            MSE_DTR,
            MSE_RFR]

model_result = pd.DataFrame([MSE_list, MSE_list_loged])

# %%
model_result.index = ['No_log', 'loged']

model_result.columns = ['MSE_LR',
                        'MSE_SVR',
                        'MSE_DTR',
                        'MSE_RFR']
model_result
# Out:
#               MSE_LR       MSE_SVR       MSE_DTR       MSE_RFR
# No_log  2.314465e+09  2.457802e+09  2.369116e+09  1.686212e+09
# loged   4.949383e-02  4.969160e-02  9.070209e-02  5.834843e-02

# %% [markdown]
# ## 対数変換、標準化がかなりきいている
# しかしなぜか決定木とランダムフォレストにも効いている

# %% [markdown]
# ## 【問題4】（アドバンス課題）他の特徴量も使用しての学習
# ここまでは練習のために2つの特徴量だけを使いましたが、他の特徴量を加えるとどのようになるか検証してください。
# どう選択・加工するかにはデータ分析が重要になってきます。
#
# Kaggleのカーネルも参考にできます。

# %%
X = (df.iloc[:, :-1])
y  = df.SalePrice

# %%
X_onehot = pd.get_dummies(X)
X_onehot.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        ...
#        'SaleType_ConLw', 'SaleType_New', 'SaleType_Oth', 'SaleType_WD',
#        'SaleCondition_Abnorml', 'SaleCondition_AdjLand',
#        'SaleCondition_Alloca', 'SaleCondition_Family', 'SaleCondition_Normal',
#        'SaleCondition_Partial'],
#       dtype='object', length=289)

# %%
X_onehot_nomiss = X_onehot.fillna(df.mean())

# %%
X_np = np.array(X_onehot_nomiss)

# %%
X_all_log = np.log(X_np)
y_all_log = np.log(np.array(y))
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_all_log, y_all_log, test_size=0.25, random_state=42)

# %%
rfr = RandomForestRegressor()
rfr.fit(X_train_scaled, y_train_all_log)
predict_rfr = rfr.predict(X_test_scaled)
print('RandomForestRegressor')
print('mean_squared_error = {}'.format(mean_squared_error(y_test, predict_rfr)))
# Out:
# RandomForestRegressor
# mean_squared_error = 0.058769090861312136
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %% [markdown]
# 若干悪くなった。
